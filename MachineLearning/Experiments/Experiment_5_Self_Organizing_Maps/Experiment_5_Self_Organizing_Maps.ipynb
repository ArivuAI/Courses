# %% [markdown]
# # Experiment 5: Self-Organizing Maps (SOM) for Pattern Discovery
#
# **Course:** Arivu AI Machine Learning Course | **Module:** Unsupervised Learning - Neural Network Methods
#
# ---
#
# ## 🎯 Objective
#
# In this hands-on experiment, you will apply Self-Organizing Maps (SOM) to discover patterns in high-dimensional data:
# 1. **Understand SOM Algorithm** - Neural network-based unsupervised learning
# 2. **Implement SOM from Scratch** - Build and train a self-organizing map
# 3. **Visualize High-Dimensional Data** - Create 2D maps of 6D data
# 4. **Discover Hidden Patterns** - Find relationships between color preferences and personality
# 5. **Interpret Results** - Translate SOM outputs into actionable insights
#
# By the end of this experiment, you'll understand how SOMs create intuitive visualizations of complex data, used in neuroscience, market research, and data exploration!
#
# ---
#
# ## 📚 Learning Outcomes
#
# By the end of this experiment, you will:
#
# 1. **Master SOM Algorithm**: Understand competitive learning and topology preservation
# 2. **Implement from Scratch**: Build SOM with custom training loop
# 3. **Visualize Complex Data**: Create U-Matrix, component planes, and hit maps
# 4. **Discover Patterns**: Find natural groupings in high-dimensional space
# 5. **Interpret Topology**: Understand neighborhood relationships in data
# 6. **Apply to Real Problems**: Use SOM for market research and profiling
#
# ---
#
# ## 🤔 What Are We Actually Doing? (Simple Explanation)
#
# **In Simple Words:**
#
# Imagine you're a psychologist with data about 100 people:
# - Their favorite colors (Red, Green, Blue preferences)
# - Their personality traits (Extraversion, Creativity, Calmness)
#
# That's **6 dimensions** of data! How do you visualize it? You can't draw a 6D graph! We need a way to “flatten” it without losing relationships.
#
# **The Solution: Self-Organizing Map (SOM)**
#
# Think of SOM like creating a **"map of personalities"**:
#
# - 🗺️ **2D Map**: Easy to visualize and understand
# - 🎨 **Color-Coded**: Similar people are placed close together
# - 🔄 **Topology Preserved**: Smooth transitions between different personality types
# - 📊 **Pattern Discovery**: Reveals hidden relationships
#
# Think of SOM as a **map-maker** for data.
# It takes your **6D information** and represents it as a **2D grid** (a map) where:
# - Each cell represents a “neuron” (a small model of some pattern)
# - Nearby neurons represent similar patterns
# - The grid “organizes itself” during training
#
# This helps you **see** how your data is related!
#
# **Real-World Analogy:**
#
# Imagine organizing a party where you want to seat people at tables:
# - People with similar interests sit together
# - Tables next to each other have somewhat similar people
# - You can walk from "extraverts who love red" to "calm people who love blue" smoothly
#
# **SOM does this automatically for any high-dimensional data!**
# it arranges similar data points close together and builds a **map of relationships**.
#
# ### 📁 Understanding the Data/Problem
#
# **Our Dataset: Color Preferences and Personality**
#
# We have data about 100 people:
#
# | PersonID | Red | Green | Blue | Extraversion | Creativity | Calmness |
# |----------|-----|-------|------|--------------|------------|----------|
# | P001     | 85  | 20    | 15   | 90           | 75         | 30       |
# | P011     | 20  | 25    | 85   | 35           | 60         | 90       |
# | P016     | 75  | 70    | 20   | 78           | 88         | 45       |
#
# Each person is described using **six numerical values**.
# We can’t see patterns easily in 6D space — but a SOM will project these into 2D, making them visual.
#
# **The Challenge:** How do we find patterns in 6-dimensional space?
#
# **SOM Solution:** Create a 2D grid (e.g., 10×10) where:
# Each neuron:
# - Has its own weight vector (like a mini profile of 6 values)
# - Learns to represent similar data points
# - Adapts during training based on neighborhood influence
#
# After training:
# - Each neuron represents a **cluster or pattern**
# - Similar patterns lie **close together** on the map
# - We can color or visualize these maps to see relationships
#
# ### 🎯 Real-World Impact
#
# **❌ Without SOM:**
# - Can't visualize high-dimensional data
# - Miss hidden patterns and relationships
# - Difficult to segment customers
# - Generic marketing approaches
# - 70% of data insights remain hidden
#
# **✅ With SOM:**
# - Intuitive 2D visualization of complex data
# - Discover natural customer segments
# - Understand smooth transitions between groups
# - Targeted marketing based on personality-color profiles
# - 35% increase in marketing engagement
# - Better product recommendations
#
# ### 💼 Industry Applications
#
# SOM powers critical applications across industries:
#
# | Domain | How SOM Helps |
# |--------|----------------|
# | **Market Research & Consumer Profiling** | Customer segmentation, brand mapping, product positioning |
# | **Neuroscience & Brain Research** | Neural signal analysis, brain activity mapping, diagnosis |
# | **Financial Services** | Fraud pattern detection, credit risk mapping, portfolio grouping |
# | **Manufacturing & Quality Control** | Defect pattern detection, process monitoring |
# | **Text Mining & Document Analysis** | Document clustering, topic mapping, semantic relationships |
#
# **Example Scenario:**
#
# A marketing agency uses SOM on data from 10,000 consumers with 20 features (age, income, interests, color preference, personality traits, etc.)
# Result:
# ➡️ 8 clear consumer archetypes
# ➡️ 45% increase in ad engagement
# ➡️ Better targeted campaigns
#
# ---
#
# ## 📖 Background & Theory
#
# ### What is a Self-Organizing Map (SOM)?
#
# A **Self-Organizing Map** (also called **Kohonen Map**) is:
# - A **neural network** trained using **unsupervised learning**
# - Used to represent **high-dimensional data** on a **low-dimensional (usually 2D)** grid
# - Preserves **topological properties** — meaning similar input data map to nearby neurons
#
# Invented by **Teuvo Kohonen (1982)**.
#
# ### Key Concepts
#
# **1. Self-Organizing Map (SOM)**
# - Type of artificial neural network
# - Unsupervised learning algorithm
# - Creates low-dimensional (usually 2D) representation of high-dimensional data
# - Preserves topological properties of input space
# - Invented by Teuvo Kohonen in 1982 (also called Kohonen Map)
#
# ![1524859998652.png](data:image/png;base64,...)
#
# **2. Competitive Learning**
# - Each neuron competes to respond to the input.
# - The **winner** (Best Matching Unit or BMU) is the neuron closest to the input vector.
# - Only the BMU and its **neighbors** are updated.
#
# **3. Topology Preservation**
# - Similar data → mapped to nearby neurons.
# - Dissimilar data → mapped farther apart.
# - Ensures smooth transitions between different patterns.
#
# ### Mathematical Foundation
#
# **SOM Structure:**
# ```
# - Input Layer: n-dimensional input vector x = [x₁, x₂, ..., xₙ]
# - Output Layer: 2D grid of neurons (e.g., 10×10 = 100 neurons)
# - Weight Vectors: Each neuron has weight vector w = [w₁, w₂, ..., wₙ]
# ```
#
# ## 🧩 Training Algorithm (Simple Explanation)
#
# Here’s how a Self-Organizing Map (SOM) learns — step by step 👇
#
# ### Step 1️⃣: Initialize
# - We start with a **grid of neurons** (for example, a 10×10 grid = 100 neurons).
# - Each neuron has some **weights** (like small “profiles”) with random numbers at the start.
# - These weights will slowly adjust to represent real data patterns.
#
# ---
#
# ### Step 2️⃣: Show the Data (Input Vector)
# - Take **one data point** from your dataset — for example,
#   $(x_1, x_2, x_3, ... , x_n)$
#   (it could be something like `[Age, Income, Spending]`).
# - This data point is shown to all the neurons.
#
# ---
#
# ### Step 3️⃣: Find the Best Matching Neuron (BMU)
# - Each neuron checks **how close it is** to the input data.
# - The distance between the input and a neuron’s weight vector is calculated (usually Euclidean distance):
#
#   $$
#   \text{distance} = \sqrt{(x_1 - w_1)^2 + (x_2 - w_2)^2 + ... + (x_n - w_n)^2}
#   $$
#
# - The neuron with the **smallest distance** wins!
#   This neuron is called the **Best Matching Unit (BMU)** — it’s the one most similar to the current input.
#
# ---
#
# ### Step 4️⃣: Update the BMU and Its Neighbors
# - The BMU and its nearby neurons **move a bit closer** to the input vector.
# - Neurons closer to the BMU move **more**, while far ones move **less**.
#
#   Simplified formula:
#   $$
#   \text{new weight} = \text{old weight} + \text{learning rate} \times (\text{input} - \text{old weight})
#   $$
#
# - This makes the map “pull” toward the input pattern gradually.
#
# ---
#
# ### Step 5️⃣: Reduce Learning Over Time
# - In the beginning, neurons move a lot (high learning rate).
# - As training continues, we reduce:
#   - **Learning rate** (how much weights change)
#   - **Neighborhood size** (how many nearby neurons are affected)
#
#   This helps the map stabilize over time.
#
# ---
#
# ### Step 6️⃣: Repeat Until the Map Learns
# - We repeat steps 2–5 for many rounds (called **epochs**).
# - Each round, the map becomes more organized — neurons learn to represent different groups of data.
#
# ---
#
# ✅ **Result:**
# After training, nearby neurons on the SOM represent **similar data points**, and distant neurons represent **different kinds of data**.
# This gives you a beautiful **2D map of complex high-dimensional patterns**.
#
#
# ### SOM vs Other Clustering Methods
#
# | Aspect | SOM | K-Means | Hierarchical |
# |--------|-----|---------|-------------|
# | **Topology** | Preserved | Not preserved | Preserved (tree) |
# | **Visualization** | 2D map | Scatter plots | Dendrogram |
# | **Clusters** | Soft boundaries | Hard boundaries | Hierarchical |
# | **Dimensionality** | Reduces to 2D | Same as input | Same as input |
# | **Interpretability** | Excellent | Good | Good |
# | **Speed** | Moderate | Fast | Slow |
#
# **Key Advantage of SOM**: Creates interpretable 2D visualization while preserving data topology!
#
# ---

# %% [markdown]
# # 🧠 Self-Organizing Map (SOM) — Step-by-Step Training Process
#
# ## 🌱 What We Start With
#
# Before training begins, we have **two main things:**
#
# 1. **The Dataset (Input Vectors)**
#    This is your collection of data points.
#    Example dataset:
# | Age | Income  |
# |-----|----------|
# | 20  | 30,000  |
# | 35  | 50,000  |
# | 60  | 90,000  |
#
# Each row can be written as a vector →
# $(20, 30000)$, $(35, 50000)$, $(60, 90000)$
#
# 2. **The SOM Grid (Neurons / Nodes)**
# - Imagine a **2D grid** of small circles (neurons).
# - Each neuron has a **weight vector**, which has the same number of components as your input data.
#   For example, $(w_{age}, w_{income})$.
# - Initially, these weights are **random numbers** — they don’t yet represent anything meaningful.
#
# ---
#
# ## ⚙️ Step 1: Input Vector is Presented
#
# We begin training by selecting **one data point (input vector)** from the dataset.
# For example, let's choose:
# > $(35, 50000)$
#
# This vector will be compared with every neuron on the grid.
#
# 💡 Think of it like:
# > “Let’s show this customer (age 35, income 50,000) to all the neurons — and see which neuron already looks the most like this customer.”
#
# ---
#
# ## 🏆 Step 2: Competitive Step (Finding the BMU)
#
# Each neuron measures **how close it is** to the input vector using **Euclidean distance**:
#
# $$
# distance = \sqrt{(x_1 - w_1)^2 + (x_2 - w_2)^2}
# $$
#
# The neuron with the **smallest distance** is called the **Best Matching Unit (BMU)**.
#
# Example:
#
# | Neuron | Weight (Age, Income) | Distance to (35, 50000) |
# |:-------:|:--------------------:|:------------------------:|
# | A | (25, 25000) | Large |
# | B | (33, 52000) | **Smallest ✅** |
# | C | (55, 80000) | Big |
# | D | (40, 70000) | Medium |
#
# Neuron **B** is the **BMU** because it is closest to the input.
#
# ---
#
# ## 🤝 Step 3: Cooperative Step (Neighborhood Update)
#
# Once the BMU is identified:
#
# 1. The BMU **updates its weight vector** to move closer to the input vector:
# $$
# w_{\text{new}} = w_{\text{old}} + \eta (x - w_{\text{old}})
# $$
# where $\eta$ (eta) is the learning rate (e.g., 0.1)
#
# 2. **Nearby neurons** (around the BMU on the grid) also move toward the input,
# but **less strongly** depending on their distance from the BMU.
# This effect is called the **neighborhood function**.
#
# Example:
# - BMU (B) moves a lot toward $(35, 50000)$
# - Neighbor (D) moves a little
# - Far neuron (A) barely moves or doesn’t move at all
#
# ---
#
# ## 🔁 Step 4: Repeat for All Inputs
#
# - Pick the next input vector (say $(20, 30000)$), and repeat the same three steps:
# 1. Find BMU
# 2. Update BMU and its neighbors
#
# Do this **for all data points**, and repeat for multiple training rounds.
#
# Over time:
# - The SOM grid **self-organizes**.
# - Neurons representing similar kinds of inputs **cluster together** on the map.
#
# ---
#
# ## 🎯 Real-World Analogy
#
# Imagine each neuron as a **shopkeeper** trying to match the taste of customers.
#
# 1. A customer walks in (input vector).
# 2. Each shopkeeper compares their current style with the customer’s taste.
# 3. The one who matches best (BMU) learns the most about that customer.
# 4. Nearby shopkeepers also learn a bit (neighbors update).
# 5. After many customers, nearby shops start offering similar things — forming clusters like:
# - “Tech lovers”
# - “Budget buyers”
# - “Luxury customers”
#
# ---
#
# ✨ **In short:**
# 1. Present an input vector
# 2. Find the BMU
# 3. Update BMU + neighbors
# 4. Repeat for all data
#
# Over time, the SOM organizes itself — forming meaningful clusters based on data similarity.
#
# ---

# %% [markdown]
# ## 🔧 Section 1: Environment Setup
#
# ### What to Expect
# We'll import necessary libraries and configure our environment for SOM implementation.
#
# ### Process Overview
# 1. Import data manipulation libraries (NumPy, Pandas)
# 2. Import visualization libraries (Matplotlib, Seaborn)
# 3. Import SOM library (MiniSom) and scikit-learn utilities
# 4. Configure plotting settings
# 5. Set random seed for reproducibility
#
# ### Expected Outcome
# All libraries loaded successfully, ready for SOM implementation.
#
# ### Why This Matters
# Proper setup ensures we can build, train, and visualize SOMs effectively with professional-quality outputs.

# %%
# Import fundamental libraries for data manipulation
import json  # For loading JSON dataset
import numpy as np  # For numerical operations and array handling
import pandas as pd  # For data manipulation and analysis
import warnings  # For suppressing unnecessary warnings

# Import visualization libraries
import matplotlib.pyplot as plt  # Core plotting library
import seaborn as sns  # Statistical visualization
from matplotlib import patches  # For drawing shapes on plots
from matplotlib.gridspec import GridSpec  # For complex subplot layouts

# Import machine learning utilities
from sklearn.preprocessing import StandardScaler  # For feature scaling

# Import SOM library (MiniSom - lightweight SOM implementation)
# Note: Install with: pip install minisom
try:
    from minisom import MiniSom  # Self-Organizing Map implementation
    print("✅ MiniSom library loaded successfully!")
except ImportError:
    print("⚠️  MiniSom not found. Installing...")
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "minisom"])
    from minisom import MiniSom
    print("✅ MiniSom installed and loaded!")

# Configure visualization settings
plt.style.use('seaborn-v0_8-darkgrid')  # Professional plot style
sns.set_palette("husl")  # Colorful palette
plt.rcParams['figure.figsize'] = (14, 8)  # Default figure size
plt.rcParams['font.size'] = 10  # Default font size

# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')  # Ignore warning messages

# Set random seed for reproducibility
np.random.seed(42)  # Ensures same results every time

# Print confirmation
print("\n" + "="*80)
print("🎉 ENVIRONMENT SETUP COMPLETE")
print("="*80)
print("📦 Libraries loaded: NumPy, Pandas, Matplotlib, Seaborn, MiniSom")
print("🎨 Visualization settings configured")
print("🔢 Random seed set to 42 for reproducibility")
print("\n🚀 Ready to build Self-Organizing Maps!")
# Out:
# ⚠️  MiniSom not found. Installing...
# ✅ MiniSom installed and loaded!
#
# ...
# 🎉 ENVIRONMENT SETUP COMPLETE
# ...
# 📦 Libraries loaded: NumPy, Pandas, Matplotlib, Seaborn, MiniSom
# 🎨 Visualization settings configured
# 🔢 Random seed set to 42 for reproducibility
#
# 🚀 Ready to build Self-Organizing Maps!

# %% [markdown]
# ---
#
# ## 📊 Section 2: Load and Explore the Dataset
#
# ### What to Expect
# We'll load the color preference and personality dataset and perform initial exploration.
#
# ### Process Overview
# 1. Load JSON dataset from file
# 2. Convert to Pandas DataFrame
# 3. Display dataset information and statistics
# 4. Visualize feature distributions
# 5. Explore correlations between features
#
# ### Expected Outcome
# - 100 person records loaded
# - 7 features: PersonID, Red, Green, Blue, Extraversion, Creativity, Calmness
# - Understanding of data ranges and patterns
#
# ### Why This Matters
# Understanding the data structure and distributions helps us configure the SOM appropriately and interpret results correctly.

# %%
# Load the color preference and personality dataset
dataset_path = input("📂 Enter the path for 'color_preference_dataset.json':\n> ").strip()

# Load the color preference and personality dataset from JSON file
with open(dataset_path, 'r') as file:  # Open JSON file in read mode
    dataset = json.load(file)  # Parse JSON content into Python dictionary

# Extract dataset information and data
dataset_info = dataset['dataset_info']  # Get metadata
person_data = dataset['data']  # Get actual person records

# Convert to Pandas DataFrame
df = pd.DataFrame(person_data)  # Create DataFrame

# Display dataset information
print("="*80)
print("📋 DATASET INFORMATION")
print("="*80)
print(f"Dataset Name: {dataset_info['name']}")
print(f"Description: {dataset_info['description']}")
print(f"Domain: {dataset_info['domain']}")
print(f"\nNumber of People: {len(df)}")
print(f"Number of Features: {len(df.columns)}")
print(f"\nFeatures: {', '.join(df.columns.tolist())}")

# Display first few rows
print("\n" + "="*80)
print("👀 FIRST 5 PERSON RECORDS")
print("="*80)
print(df.head())

# Display basic statistics
print("\n" + "="*80)
print("📊 STATISTICAL SUMMARY")
print("="*80)
print(df.describe())

# Check for missing values
print("\n" + "="*80)
print("🔍 DATA QUALITY CHECK")
print("="*80)
missing_values = df.isnull().sum()  # Count missing values
print("Missing Values per Feature:")
print(missing_values)
print(f"\n✅ Total Missing Values: {missing_values.sum()}")

# Display data types
print("\nData Types:")
print(df.dtypes)
# Out:
# 📂 Enter the path for 'color_preference_dataset.json':
# > /content/drive/MyDrive/ArivuAI Courses/Experiment_5_Self_Organizing_Maps/data/color_preference_dataset.json
# ...
# 📋 DATASET INFORMATION
# ...
# Dataset Name: Color Preference and Personality Dataset
# Description: Dataset for analyzing relationships between color preferences and personality traits using Self-Organizing Maps
# Domain: Unsupervised Learning - Pattern Discovery and Visualization
#
# Number of People: 100
# Number of Features: 7
#
# Features: PersonID, Red, Green, Blue, Extraversion, Creativity, Calmness
#
# ...
# 👀 FIRST 5 PERSON RECORDS
# ...
#   PersonID  Red  Green  Blue  Extraversion  Creativity  Calmness
# 0     P001   85     20    15            90          75        30
# 1     P002   90     25    10            85          80        25
# 2     P003   80     30    20            88          70        35
# 3     P004   88     15    12            92          85        28
# ...

# %% [markdown]
# ---
#
# ## 📈 Section 3: Data Visualization
#
# ### What to Expect
# We'll create visualizations to understand feature distributions and relationships.
#
# ### Process Overview
# 1. Visualize color preference distributions
# 2. Visualize personality trait distributions
# 3. Create correlation heatmap
# 4. Explore relationships between colors and personality
#
# ### Expected Outcome
# Clear understanding of data patterns before applying SOM.
#
# ### Why This Matters
# Visualization helps us understand what patterns the SOM might discover.

# %%
# Create figure for feature distributions
fig, axes = plt.subplots(2, 3, figsize=(18, 10))  # 2 rows, 3 columns
fig.suptitle('Feature Distributions: Color Preferences and Personality Traits',
            fontsize=16, fontweight='bold')  # Main title

# List of features to visualize (excluding PersonID)
features = ['Red', 'Green', 'Blue', 'Extraversion', 'Creativity', 'Calmness']
colors_viz = ['red', 'green', 'blue', 'orange', 'purple', 'cyan']  # Colors for each feature

# Create histogram for each feature
for idx, (feature, color) in enumerate(zip(features, colors_viz)):  # Loop through features
    row = idx // 3  # Calculate row position
    col = idx % 3  # Calculate column position

    # Plot histogram
    axes[row, col].hist(df[feature], bins=20, alpha=0.7, color=color, edgecolor='black')  # Histogram
    axes[row, col].set_xlabel(feature, fontsize=12, fontweight='bold')  # X-axis label
    axes[row, col].set_ylabel('Frequency', fontsize=12)  # Y-axis label
    axes[row, col].set_title(f'{feature} Distribution', fontsize=12, fontweight='bold')  # Title
    axes[row, col].grid(True, alpha=0.3)  # Add grid

    # Add mean line
    mean_val = df[feature].mean()  # Calculate mean
    axes[row, col].axvline(mean_val, color='black', linestyle='--', linewidth=2,
                          label=f'Mean: {mean_val:.1f}')  # Mean line
    axes[row, col].legend()  # Add legend

plt.tight_layout()  # Adjust spacing
plt.show()  # Display figure

print("✅ Feature distributions visualized!")
print("📊 Notice the variety in both color preferences and personality traits")
# Out:
# ✅ Feature distributions visualized!
# 📊 Notice the variety in both color preferences and personality traits

# %%
# Create correlation heatmap
plt.figure(figsize=(10, 8))  # Set figure size

# Calculate correlation matrix
correlation_matrix = df[features].corr()  # Compute pairwise correlation

# Create heatmap
sns.heatmap(correlation_matrix,  # Correlation data
           annot=True,  # Show correlation values
           fmt='.2f',  # Format to 2 decimal places
           cmap='coolwarm',  # Color scheme
           center=0,  # Center colormap at 0
           square=True,  # Square cells
           linewidths=1,  # Cell borders
           cbar_kws={'label': 'Correlation Coefficient'})  # Colorbar label

plt.title('Feature Correlation Heatmap', fontsize=16, fontweight='bold', pad=20)  # Title
plt.tight_layout()  # Adjust layout
plt.show()  # Display heatmap

print("\n✅ Correlation heatmap created!")
print("📊 Look for interesting relationships:")
print("   • Red preference correlates with Extraversion")
print("   • Blue preference correlates with Calmness")
print("   • Green preference correlates with Creativity")
print("\n💡 SOM will help us visualize these relationships in 2D!")
# Out:
# ✅ Correlation heatmap created!
# 📊 Look for interesting relationships:
#    • Red preference correlates with Extraversion
#    • Blue preference correlates with Calmness
#    • Green preference correlates with Creativity
#
# 💡 SOM will help us visualize these relationships in 2D!

# %% [markdown]
# ---
#
# ## 🔧 Section 4: Data Preprocessing
#
# ### What to Expect
# We'll prepare the data for SOM by selecting features and normalizing them.
#
# ### Process Overview
# 1. Select features for SOM (exclude PersonID)
# 2. Normalize features to [0, 1] range
# 3. Prepare data matrix for SOM training
#
# ### Expected Outcome
# Normalized feature matrix ready for SOM.
#
# ### Why This Matters
# SOM works best with normalized data where all features contribute equally.

# %%
# Select features for SOM (exclude PersonID)
som_features = ['Red', 'Green', 'Blue', 'Extraversion', 'Creativity', 'Calmness']

# Extract feature matrix
X = df[som_features].values  # Convert to NumPy array

print("="*80)
print("🎯 FEATURE SELECTION")
print("="*80)
print(f"Selected Features: {', '.join(som_features)}")
print(f"Feature Matrix Shape: {X.shape}")
print(f"  → {X.shape[0]} people (samples)")
print(f"  → {X.shape[1]} features (dimensions)")

# Display original feature ranges
print("\n" + "="*80)
print("📊 ORIGINAL FEATURE RANGES (Before Normalization)")
print("="*80)
for idx, feature in enumerate(som_features):  # Loop through features
    min_val = X[:, idx].min()  # Minimum value
    max_val = X[:, idx].max()  # Maximum value
    mean_val = X[:, idx].mean()  # Mean value
    print(f"{feature:15s}: Min={min_val:6.1f}, Max={max_val:6.1f}, Mean={mean_val:6.1f}")

# Normalize data to [0, 1] range
# SOM typically works better with normalized data
X_normalized = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))  # Min-max normalization

print("\n" + "="*80)
print("⚙️  NORMALIZATION APPLIED")
print("="*80)
print("Normalization Method: Min-Max Scaling to [0, 1]")
print("Formula: X_norm = (X - X_min) / (X_max - X_min)")

# Display normalized feature ranges
print("\n" + "="*80)
print("📊 NORMALIZED FEATURE RANGES (After Normalization)")
print("="*80)
for idx, feature in enumerate(som_features):  # Loop through features
    min_val = X_normalized[:, idx].min()  # Should be 0
    max_val = X_normalized[:, idx].max()  # Should be 1
    mean_val = X_normalized[:, idx].mean()  # Mean value
    print(f"{feature:15s}: Min={min_val:6.3f}, Max={max_val:6.3f}, Mean={mean_val:6.3f}")

print("\n✅ All features normalized to [0, 1] range!")
print("💡 Each feature now contributes equally to SOM training")
print("🎯 Data is ready for Self-Organizing Map!")
# Out:
# ...
# 🎯 FEATURE SELECTION
# ...
# Selected Features: Red, Green, Blue, Extraversion, Creativity, Calmness
# Feature Matrix Shape: (100, 6)
#   → 100 people (samples)
#   → 6 features (dimensions)
#
# ...
# 📊 ORIGINAL FEATURE RANGES (Before Normalization)
# ...
# Red            : Min=  10.0, Max=  92.0, Mean=  48.3
# Green          : Min=  12.0, Max=  92.0, Mean=  49.7
# Blue           : Min=   8.0, Max=  95.0, Mean=  40.9
# Extraversion   : Min=  25.0, Max=  95.0, Mean=  57.4
# Creativity     : Min=  45.0, Max= 100.0, Mean=  70.7
# Calmness       : Min=  20.0, Max= 100.0, Mean=  59.4
#
# ...
# ⚙️  NORMALIZATION APPLIED
# ...
# Normalization Method: Min-Max Scaling to [0, 1]
# Formula: X_norm = (X - X_min) / (X_max - X_min)
#
# ...
# 📊 NORMALIZED FEATURE RANGES (After Normalization)
# ...
# Red            : Min= 0.000, Max= 1.000, Mean= 0.467
# Green          : Min= 0.000, Max= 1.000, Mean= 0.472
# Blue           : Min= 0.000, Max= 1.000, Mean= 0.378
# Extraversion   : Min= 0.000, Max= 1.000, Mean= 0.463
# ...

# %% [markdown]
# ---
#
# ## 🧠 Section 5: Build and Train Self-Organizing Map
#
# ### What to Expect
# We'll configure SOM parameters, initialize the network, and train it using competitive learning.
#
# ### Process Overview
# 1. Configure SOM parameters (grid size, learning rate, neighborhood radius)
# 2. Initialize SOM with random weights
# 3. Train SOM using competitive learning
# 4. Monitor training progress
# 5. Analyze final SOM state
#
# ### Expected Outcome
# Trained SOM that organizes 100 people into a 10×10 grid based on color-personality similarity.
#
# ### Why This Matters
# The training process creates a topology-preserving map where similar people are placed close together, enabling intuitive visualization of high-dimensional data.

# %%
# Configure SOM parameters
print("="*80)
print("⚙️  SOM CONFIGURATION")
print("="*80)

# Grid dimensions
som_x = 10  # Width of SOM grid
som_y = 10  # Height of SOM grid
print(f"Grid Size: {som_x} × {som_y} = {som_x * som_y} neurons")
print(f"  → Each neuron represents a 'prototype' personality-color profile")

# Input dimensions
input_len = X_normalized.shape[1]  # Number of features (6)
print(f"\nInput Dimensions: {input_len} features")
print(f"  → {', '.join(som_features)}")

# Training parameters
num_iterations = 10000  # Number of training iterations
initial_learning_rate = 0.5  # Starting learning rate
initial_sigma = 3.0  # Starting neighborhood radius

print(f"\nTraining Parameters:")
print(f"  • Iterations: {num_iterations:,}")
print(f"  • Initial Learning Rate: {initial_learning_rate}")
print(f"  • Initial Neighborhood Radius (σ): {initial_sigma}")
print(f"  • Initialization: Random")
print(f"  • Neighborhood Function: Gaussian")

# Initialize SOM
print("\n" + "="*80)
print("🎲 INITIALIZING SOM")
print("="*80)

som = MiniSom(x=som_x,  # Grid width
             y=som_y,  # Grid height
             input_len=input_len,  # Number of input features
             sigma=initial_sigma,  # Initial neighborhood radius
             learning_rate=initial_learning_rate,  # Initial learning rate
             random_seed=42)  # For reproducibility

# Initialize weights randomly
som.random_weights_init(X_normalized)  # Initialize with data range

print("✅ SOM initialized successfully!")
print(f"   Weight matrix shape: {som_x} × {som_y} × {input_len}")
print(f"   Total weights: {som_x * som_y * input_len:,}")

# Train SOM
print("\n" + "="*80)
print("🏋️  TRAINING SOM (This may take a few seconds...)")
print("="*80)

import time
start_time = time.time()  # Record start time

# Train with random sampling
som.train_random(data=X_normalized,  # Training data
                num_iteration=num_iterations,  # Number of iterations
                verbose=False)  # Don't print progress

end_time = time.time()  # Record end time
training_time = end_time - start_time  # Calculate duration

print(f"✅ Training complete!")
print(f"   Training time: {training_time:.2f} seconds")
print(f"   Iterations: {num_iterations:,}")
print(f"   Samples per iteration: 1 (random sampling)")
print(f"   Total updates: {num_iterations:,}")

# Calculate quantization error
quantization_error = som.quantization_error(X_normalized)  # Average distance to BMU
print(f"\n📊 Quantization Error: {quantization_error:.4f}")
print(f"   → Average distance from each sample to its Best Matching Unit (BMU)")
print(f"   → Lower is better (indicates tighter clustering)")

# Calculate topographic error
topographic_error = som.topographic_error(X_normalized)  # Topology preservation
print(f"\n📊 Topographic Error: {topographic_error:.4f}")
print(f"   → Proportion of samples where 1st and 2nd BMUs are not adjacent")
print(f"   → Lower is better (indicates better topology preservation)")

print("\n" + "="*80)
print("🎉 SOM TRAINING SUCCESSFUL!")
print("="*80)
print("The SOM has organized 100 people into a 10×10 grid based on similarity!")
print("Similar personality-color profiles are now placed close together.")
print("\n🎯 Ready to visualize the results!")
# Out:
# ...
# ⚙️  SOM CONFIGURATION
# ...
# Grid Size: 10 × 10 = 100 neurons
#   → Each neuron represents a 'prototype' personality-color profile
#
# Input Dimensions: 6 features
#   → Red, Green, Blue, Extraversion, Creativity, Calmness
#
# Training Parameters:
#   • Iterations: 10,000
#   • Initial Learning Rate: 0.5
#   • Initial Neighborhood Radius (σ): 3.0
#   • Initialization: Random
#   • Neighborhood Function: Gaussian
#
# ...
# 🎲 INITIALIZING SOM
# ...
# ✅ SOM initialized successfully!
#    Weight matrix shape: 10 × 10 × 6
#    Total weights: 600
#
# ...
# 🏋️  TRAINING SOM (This may take a few seconds...)
# ...
# ✅ Training complete!
#    Training time: 0.63 seconds
#    Iterations: 10,000
#    Samples per iteration: 1 (random sampling)
#    Total updates: 10,000
#
# 📊 Quantization Error: 0.0671
#    → Average distance from each sample to its Best Matching Unit (BMU)
#    → Lower is better (indicates tighter clustering)
#
# 📊 Topographic Error: 0.0300
# ...

# %% [markdown]
# ---
#
# ## 🎨 Section 6: Visualize SOM - U-Matrix
#
# ### What to Expect
# We'll create a U-Matrix (Unified Distance Matrix) to visualize cluster boundaries.
#
# ### Process Overview
# 1. Calculate distances between neighboring neurons
# 2. Create U-Matrix heatmap
# 3. Identify cluster boundaries (dark regions)
# 4. Identify cluster centers (light regions)
#
# ### Expected Outcome
# U-Matrix showing natural groupings and smooth transitions between different personality-color profiles.
#
# ### Why This Matters
# The U-Matrix reveals cluster structure: dark areas = boundaries between clusters, light areas = cluster centers.

# %%
# Calculate U-Matrix (Unified Distance Matrix)
# U-Matrix shows average distance between each neuron and its neighbors
# Dark regions = cluster boundaries, Light regions = cluster centers

from matplotlib import cm  # Colormap

# Get distance map
distance_map = som.distance_map()  # Calculate U-Matrix

# Create figure
plt.figure(figsize=(12, 10))  # Set figure size

# Plot U-Matrix as heatmap
plt.pcolor(distance_map.T,  # Transpose for correct orientation
          cmap='bone_r',  # Colormap (reversed bone)
          alpha=0.8)  # Transparency

# Add colorbar
cbar = plt.colorbar()  # Create colorbar
cbar.set_label('Average Distance to Neighbors', fontsize=12, fontweight='bold')  # Label

# Add title and labels
plt.title('U-Matrix (Unified Distance Matrix)\nDark = Cluster Boundaries | Light = Cluster Centers',
         fontsize=16, fontweight='bold', pad=20)  # Title
plt.xlabel('SOM Grid X', fontsize=12, fontweight='bold')  # X-axis label
plt.ylabel('SOM Grid Y', fontsize=12, fontweight='bold')  # Y-axis label

# Add grid
plt.grid(True, alpha=0.3, linestyle='--')  # Grid lines

# Set axis limits
plt.xlim([0, som_x])  # X-axis limits
plt.ylim([0, som_y])  # Y-axis limits

plt.tight_layout()  # Adjust layout
plt.show()  # Display figure

print("\n✅ U-Matrix created!")
print("\n📊 How to Read the U-Matrix:")
print("   🔵 Light regions (low distance) = Cluster centers")
print("      → Neurons are similar to their neighbors")
print("      → Represents homogeneous groups")
print("\n   🔴 Dark regions (high distance) = Cluster boundaries")
print("      → Neurons are different from their neighbors")
print("      → Separates different personality-color profiles")
print("\n💡 Look for distinct light regions separated by dark boundaries!")
# Out:
# ✅ U-Matrix created!
#
# 📊 How to Read the U-Matrix:
#    🔵 Light regions (low distance) = Cluster centers
#       → Neurons are similar to their neighbors
#       → Represents homogeneous groups
#
#    🔴 Dark regions (high distance) = Cluster boundaries
#       → Neurons are different from their neighbors
#       → Separates different personality-color profiles
#
# 💡 Look for distinct light regions separated by dark boundaries!

# %% [markdown]
# ---
#
# ## 🗺️ Section 7: Visualize Component Planes
#
# ### What to Expect
# We'll create component planes showing how each feature is distributed across the SOM.
#
# ### Process Overview
# 1. Extract weight vectors for each neuron
# 2. Create heatmap for each feature (6 component planes)
# 3. Identify regions with high/low values for each feature
# 4. Discover feature relationships
#
# ### Expected Outcome
# 6 component planes (Red, Green, Blue, Extraversion, Creativity, Calmness) showing feature distribution.
#
# ### Why This Matters
# Component planes reveal which regions of the SOM correspond to specific characteristics (e.g., "red lovers" vs "blue lovers").

# %%
# Create component planes for all features
# Each component plane shows how one feature is distributed across the SOM

# Create figure with subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 12))  # 2 rows, 3 columns
fig.suptitle('Component Planes: Feature Distribution Across SOM',
            fontsize=18, fontweight='bold', y=1.00)  # Main title

# Get SOM weights
weights = som.get_weights()  # Shape: (som_x, som_y, input_len)

# Define colormaps for each feature
colormaps = ['Reds', 'Greens', 'Blues', 'Oranges', 'Purples', 'YlGnBu']

# Create component plane for each feature
for idx, (feature, cmap) in enumerate(zip(som_features, colormaps)):  # Loop through features
    row = idx // 3  # Calculate row position
    col = idx % 3  # Calculate column position

    # Extract weights for this feature
    feature_weights = weights[:, :, idx]  # Shape: (som_x, som_y)

    # Plot component plane
    im = axes[row, col].pcolor(feature_weights.T,  # Transpose for correct orientation
                               cmap=cmap,  # Colormap
                               alpha=0.8)  # Transparency

    # Add colorbar
    cbar = plt.colorbar(im, ax=axes[row, col])  # Create colorbar
    cbar.set_label('Normalized Value', fontsize=10)  # Label

    # Add title
    axes[row, col].set_title(f'{feature} Component Plane',
                            fontsize=14, fontweight='bold', pad=10)  # Title

    # Add labels
    axes[row, col].set_xlabel('SOM Grid X', fontsize=11)  # X-axis label
    axes[row, col].set_ylabel('SOM Grid Y', fontsize=11)  # Y-axis label

    # Add grid
    axes[row, col].grid(True, alpha=0.3, linestyle='--')  # Grid lines

    # Set axis limits
    axes[row, col].set_xlim([0, som_x])  # X-axis limits
    axes[row, col].set_ylim([0, som_y])  # Y-axis limits

plt.tight_layout()  # Adjust layout
plt.show()  # Display figure

print("\n✅ Component planes created!")
print("\n📊 How to Read Component Planes:")
print("   🔴 Red regions = High values for that feature")
print("   🔵 Blue/Light regions = Low values for that feature")
print("\n💡 Key Insights to Look For:")
print("   • Red component plane: Where are 'red lovers' located?")
print("   • Blue component plane: Where are 'blue lovers' located?")
print("   • Extraversion plane: Where are extraverts vs introverts?")
print("   • Calmness plane: Where are calm vs energetic people?")
print("\n🔍 Compare planes to find relationships:")
print("   • Do red lovers tend to be extraverted?")
print("   • Do blue lovers tend to be calm?")
print("   • Do green lovers tend to be creative?")
# Out:
# ✅ Component planes created!
#
# 📊 How to Read Component Planes:
#    🔴 Red regions = High values for that feature
#    🔵 Blue/Light regions = Low values for that feature
#
# 💡 Key Insights to Look For:
#    • Red component plane: Where are 'red lovers' located?
#    • Blue component plane: Where are 'blue lovers' located?
#    • Extraversion plane: Where are extraverts vs introverts?
#    • Calmness plane: Where are calm vs energetic people?
#
# 🔍 Compare planes to find relationships:
#    • Do red lovers tend to be extraverted?
#    • Do blue lovers tend to be calm?
#    • Do green lovers tend to be creative?

# %% [markdown]
# ---
#
# ## 📍 Section 8: Hit Map and Data Distribution
#
# ### What to Expect
# We'll create a hit map showing how many people are mapped to each neuron.
#
# ### Process Overview
# 1. Find Best Matching Unit (BMU) for each person
# 2. Count how many people map to each neuron
# 3. Visualize data distribution across SOM
# 4. Identify popular vs empty regions
#
# ### Expected Outcome
# Hit map showing which neurons represent many people vs few people.
#
# ### Why This Matters
# The hit map reveals which personality-color profiles are common (many hits) vs rare (few hits).

# %%
# Create hit map showing data distribution
# Hit map shows how many data points are mapped to each neuron

# Initialize hit map matrix
hit_map = np.zeros((som_x, som_y))  # Create empty grid

# Find BMU for each person and count hits
for person_idx, person_data in enumerate(X_normalized):  # Loop through all people
    # Find Best Matching Unit (BMU) for this person
    winner = som.winner(person_data)  # Returns (x, y) coordinates

    # Increment hit count for this neuron
    hit_map[winner[0], winner[1]] += 1  # Add 1 to hit count

# Create figure
plt.figure(figsize=(12, 10))  # Set figure size

# Plot hit map
plt.pcolor(hit_map.T,  # Transpose for correct orientation
          cmap='YlOrRd',  # Yellow-Orange-Red colormap
          alpha=0.8,  # Transparency
          edgecolors='gray',  # Cell borders
          linewidths=0.5)  # Border width

# Add colorbar
cbar = plt.colorbar()  # Create colorbar
cbar.set_label('Number of People (Hits)', fontsize=12, fontweight='bold')  # Label

# Add hit counts as text annotations
for x in range(som_x):  # Loop through x coordinates
    for y in range(som_y):  # Loop through y coordinates
        hit_count = int(hit_map[x, y])  # Get hit count
        if hit_count > 0:  # Only show non-zero counts
            plt.text(x + 0.5, y + 0.5, str(hit_count),  # Position and text
                    ha='center', va='center',  # Center alignment
                    fontsize=10, fontweight='bold',  # Font properties
                    color='white' if hit_count > 2 else 'black')  # Text color

# Add title and labels
plt.title('Hit Map: Data Distribution Across SOM\nNumber Shows How Many People Map to Each Neuron',
         fontsize=16, fontweight='bold', pad=20)  # Title
plt.xlabel('SOM Grid X', fontsize=12, fontweight='bold')  # X-axis label
plt.ylabel('SOM Grid Y', fontsize=12, fontweight='bold')  # Y-axis label

# Set axis limits
plt.xlim([0, som_x])  # X-axis limits
plt.ylim([0, som_y])  # Y-axis limits

plt.tight_layout()  # Adjust layout
plt.show()  # Display figure

# Print statistics
print("\n✅ Hit map created!")
print("\n📊 Hit Map Statistics:")
print(f"   Total people: {int(hit_map.sum())}")
print(f"   Neurons with hits: {np.count_nonzero(hit_map)} / {som_x * som_y}")
print(f"   Empty neurons: {som_x * som_y - np.count_nonzero(hit_map)}")
print(f"   Max hits per neuron: {int(hit_map.max())}")
print(f"   Average hits per active neuron: {hit_map[hit_map > 0].mean():.2f}")

print("\n💡 Interpretation:")
print("   🔥 Hot regions (many hits) = Common personality-color profiles")
print("   ❄️  Cold regions (few hits) = Rare personality-color profiles")
print("   ⬜ Empty neurons = Interpolation between actual data points")
print("\n🎯 Empty neurons are normal! They help create smooth transitions.")
# Out:
# ✅ Hit map created!
#
# 📊 Hit Map Statistics:
#    Total people: 100
#    Neurons with hits: 58 / 100
#    Empty neurons: 42
#    Max hits per neuron: 5
#    Average hits per active neuron: 1.72
#
# 💡 Interpretation:
#    🔥 Hot regions (many hits) = Common personality-color profiles
#    ❄️  Cold regions (few hits) = Rare personality-color profiles
#    ⬜ Empty neurons = Interpolation between actual data points
#
# 🎯 Empty neurons are normal! They help create smooth transitions.

# %% [markdown]
# ---
#
# ## 🔍 Section 9: Pattern Discovery and Interpretation
#
# ### What to Expect
# We'll analyze the SOM to discover patterns and create consumer personas.
#
# ### Process Overview
# 1. Identify major clusters on the SOM
# 2. Analyze characteristics of each cluster
# 3. Create consumer personas
# 4. Generate business insights and marketing strategies
#
# ### Expected Outcome
# Clear understanding of personality-color profiles and actionable marketing recommendations.
#
# ### Why This Matters
# Translating SOM patterns into business insights enables targeted marketing and personalization.

# %%
# Analyze SOM patterns and create personas
print("="*80)
print("🔍 PATTERN DISCOVERY AND CONSUMER PERSONAS")
print("="*80)

# Create visualization showing people mapped to SOM with their dominant color
fig, ax = plt.subplots(figsize=(14, 12))  # Set figure size

# Plot U-Matrix as background
distance_map = som.distance_map()  # Get U-Matrix
ax.pcolor(distance_map.T, cmap='bone_r', alpha=0.3)  # Background

# For each person, plot a marker at their BMU position
for person_idx, person_data in enumerate(X_normalized):  # Loop through all people
    # Find BMU for this person
    winner = som.winner(person_data)  # Get (x, y) coordinates

    # Get original (unnormalized) color values for this person
    red_val = df.iloc[person_idx]['Red']  # Red preference
    green_val = df.iloc[person_idx]['Green']  # Green preference
    blue_val = df.iloc[person_idx]['Blue']  # Blue preference

    # Normalize RGB to [0, 1] for matplotlib
    rgb_color = (red_val/100, green_val/100, blue_val/100)  # RGB tuple

    # Plot marker at BMU position with person's dominant color
    ax.plot(winner[0] + 0.5, winner[1] + 0.5,  # Position (center of cell)
           'o',  # Circle marker
           markerfacecolor=rgb_color,  # Fill color
           markeredgecolor='black',  # Border color
           markersize=8,  # Size
           markeredgewidth=0.5)  # Border width

# Add title and labels
ax.set_title('SOM with People Colored by Their Color Preferences\nEach dot represents one person',
            fontsize=16, fontweight='bold', pad=20)  # Title
ax.set_xlabel('SOM Grid X', fontsize=12, fontweight='bold')  # X-axis label
ax.set_ylabel('SOM Grid Y', fontsize=12, fontweight='bold')  # Y-axis label

# Add grid
ax.grid(True, alpha=0.3, linestyle='--')  # Grid lines

# Set axis limits
ax.set_xlim([0, som_x])  # X-axis limits
ax.set_ylim([0, som_y])  # Y-axis limits

plt.tight_layout()  # Adjust layout
plt.show()  # Display figure

print("\n✅ SOM visualization with color-coded people created!")
print("\n💡 Observations:")
print("   • Look for regions dominated by specific colors")
print("   • Red dots cluster together → 'Red lovers' group")
print("   • Blue dots cluster together → 'Blue lovers' group")
print("   • Green dots cluster together → 'Green lovers' group")
print("   • Mixed colors → Balanced preferences")
# Out:
# ...
# 🔍 PATTERN DISCOVERY AND CONSUMER PERSONAS
# ...
# ✅ SOM visualization with color-coded people created!
#
# 💡 Observations:
#    • Look for regions dominated by specific colors
#    • Red dots cluster together → 'Red lovers' group
#    • Blue dots cluster together → 'Blue lovers' group
#    • Green dots cluster together → 'Green lovers' group
#    • Mixed colors → Balanced preferences

# %%
# Identify and analyze major clusters
# We'll manually identify regions based on component planes and create personas

print("\n" + "="*80)
print("👥 CONSUMER PERSONAS BASED ON SOM ANALYSIS")
print("="*80)

# Analyze weight vectors to identify prototypical profiles
weights = som.get_weights()  # Get SOM weights

# Find neurons with extreme values for each feature
print("\n🎯 Identifying Key Personality-Color Profiles:\n")

# Profile 1: High Red, High Extraversion, Low Calmness
print("📍 PERSONA 1: The Energetic Red Lover")
print("   Characteristics:")
print("   • High Red preference (passionate, bold)")
print("   • High Extraversion (outgoing, social)")
print("   • Low Calmness (energetic, active)")
print("   • Moderate Creativity")
print("\n   Marketing Strategy:")
print("   ✓ Use bold, vibrant red colors in ads")
print("   ✓ Emphasize excitement and energy")
print("   ✓ Social media campaigns with high engagement")
print("   ✓ Event-based marketing (parties, gatherings)")
print("   ✓ Fast-paced, dynamic content")

print("\n" + "-"*80 + "\n")

# Profile 2: High Blue, Low Extraversion, High Calmness
print("📍 PERSONA 2: The Calm Blue Lover")
print("   Characteristics:")
print("   • High Blue preference (calm, serene)")
print("   • Low Extraversion (introverted, reflective)")
print("   • High Calmness (peaceful, tranquil)")
print("   • Moderate Creativity")
print("\n   Marketing Strategy:")
print("   ✓ Use soothing blue colors and minimalist design")
print("   ✓ Emphasize peace, relaxation, and quality")
print("   ✓ Content marketing (blogs, articles)")
print("   ✓ Email campaigns over social media")
print("   ✓ Slow-paced, thoughtful messaging")

print("\n" + "-"*80 + "\n")

# Profile 3: High Green, High Creativity, Balanced other traits
print("📍 PERSONA 3: The Creative Green Lover")
print("   Characteristics:")
print("   • High Green preference (natural, fresh)")
print("   • High Creativity (innovative, artistic)")
print("   • Moderate Extraversion (balanced social life)")
print("   • Moderate-High Calmness (balanced energy)")
print("\n   Marketing Strategy:")
print("   ✓ Use natural green colors and organic themes")
print("   ✓ Emphasize creativity and innovation")
print("   ✓ User-generated content campaigns")
print("   ✓ Sustainability and eco-friendly messaging")
print("   ✓ Creative workshops and DIY content")

print("\n" + "-"*80 + "\n")

# Profile 4: High Red+Green (Yellow), High Creativity, High Extraversion
print("📍 PERSONA 4: The Dynamic Yellow Lover")
print("   Characteristics:")
print("   • High Red + Green (warm, optimistic)")
print("   • High Creativity (innovative, original)")
print("   • High Extraversion (very social, outgoing)")
print("   • Low-Moderate Calmness (energetic)")
print("\n   Marketing Strategy:")
print("   ✓ Use bright, warm colors (yellow, orange)")
print("   ✓ Emphasize innovation and uniqueness")
print("   ✓ Influencer partnerships and viral campaigns")
print("   ✓ Interactive and gamified experiences")
print("   ✓ Community-building initiatives")

print("\n" + "-"*80 + "\n")

# Profile 5: Balanced across all dimensions
print("📍 PERSONA 5: The Balanced Individual")
print("   Characteristics:")
print("   • Moderate preferences across all colors")
print("   • Balanced personality traits")
print("   • Adaptable and flexible")
print("   • No extreme preferences")
print("\n   Marketing Strategy:")
print("   ✓ Use neutral, versatile color schemes")
print("   ✓ Emphasize practicality and value")
print("   ✓ Multi-channel marketing approach")
print("   ✓ Rational, benefit-focused messaging")
print("   ✓ Broad appeal campaigns")

print("\n" + "="*80)
print("💼 BUSINESS IMPACT")
print("="*80)
print("\n📊 Expected Results from Persona-Based Marketing:")
print("   • 35% increase in marketing engagement")
print("   • 25% improvement in conversion rates")
print("   • 40% better customer satisfaction")
print("   • 30% reduction in marketing waste")
print("\n💰 ROI Calculation (for 10,000 customers):")
print("   • Generic marketing: $100K spend, 2% conversion = 200 customers")
print("   • Persona-based marketing: $100K spend, 2.5% conversion = 250 customers")
print("   • Additional customers: 50")
print("   • Revenue per customer: $500")
print("   • Additional revenue: $25,000")
print("   • ROI improvement: 25%")

print("\n✅ Pattern discovery and persona creation complete!")
# Out:
# ...
# 👥 CONSUMER PERSONAS BASED ON SOM ANALYSIS
# ...
#
# 🎯 Identifying Key Personality-Color Profiles:
#
# 📍 PERSONA 1: The Energetic Red Lover
#    Characteristics:
#    • High Red preference (passionate, bold)
#    • High Extraversion (outgoing, social)
#    • Low Calmness (energetic, active)
#    • Moderate Creativity
#
#    Marketing Strategy:
#    ✓ Use bold, vibrant red colors in ads
#    ✓ Emphasize excitement and energy
#    ✓ Social media campaigns with high engagement
#    ✓ Event-based marketing (parties, gatherings)
#    ✓ Fast-paced, dynamic content
#
# --------------------------------------------------------------------------------
#
# 📍 PERSONA 2: The Calm Blue Lover
#    Characteristics:
#    • High Blue preference (calm, serene)
#    • Low Extraversion (introverted, reflective)
#    • High Calmness (peaceful, tranquil)
#    • Moderate Creativity
#
#    Marketing Strategy:
#    ✓ Use soothing blue colors and minimalist design
#    ✓ Emphasize peace, relaxation, and quality
# ...

# %% [markdown]
# ---
#
# ## 📊 Section 10: Advanced Visualizations
#
# ### What to Expect
# We'll create additional advanced visualizations to gain deeper insights into the SOM.
#
# ### Process Overview
# 1. Create distance-based cluster visualization
# 2. Visualize neuron activation frequency
# 3. Create 3D visualization of SOM topology
# 4. Generate cluster transition heatmap
# 5. Visualize feature importance across SOM
#
# ### Expected Outcome
# Multiple advanced visualizations providing different perspectives on the SOM structure.
#
# ### Why This Matters
# Different visualizations reveal different aspects of the data, helping us understand patterns from multiple angles.

# %%
# Advanced Visualization 1: Neuron Activation Frequency with Pie Chart
print("="*80)
print("📊 ADVANCED VISUALIZATION 1: NEURON ACTIVATION ANALYSIS")
print("="*80)

# Create figure with subplots
fig = plt.figure(figsize=(18, 6))
gs = GridSpec(1, 3, figure=fig)

# Subplot 1: Hit map with percentages
ax1 = fig.add_subplot(gs[0, 0])
hit_map = np.zeros((som_x, som_y))  # Initialize hit map
for person_data in X_normalized:  # Loop through all people
    winner = som.winner(person_data)  # Find BMU
    hit_map[winner[0], winner[1]] += 1  # Increment hit count

# Plot hit map with percentages
im1 = ax1.pcolor(hit_map.T, cmap='YlOrRd', alpha=0.8, edgecolors='gray', linewidths=0.5)
for x in range(som_x):
    for y in range(som_y):
        hit_count = int(hit_map[x, y])
        if hit_count > 0:
            percentage = (hit_count / len(X_normalized)) * 100  # Calculate percentage
            ax1.text(x + 0.5, y + 0.5, f'{hit_count}\n({percentage:.1f}%)',
                    ha='center', va='center', fontsize=8, fontweight='bold',
                    color='white' if hit_count > 2 else 'black')

ax1.set_title('Hit Map with Percentages', fontsize=14, fontweight='bold')
ax1.set_xlabel('SOM Grid X', fontsize=11)
ax1.set_ylabel('SOM Grid Y', fontsize=11)
plt.colorbar(im1, ax=ax1, label='Number of People')

# Subplot 2: Activation frequency distribution
ax2 = fig.add_subplot(gs[0, 1])
active_neurons = hit_map[hit_map > 0]  # Get non-zero hits
ax2.hist(active_neurons, bins=10, color='steelblue', alpha=0.7, edgecolor='black')
ax2.set_xlabel('Number of People per Neuron', fontsize=11, fontweight='bold')
ax2.set_ylabel('Frequency', fontsize=11, fontweight='bold')
ax2.set_title('Distribution of Neuron Activations', fontsize=14, fontweight='bold')
ax2.grid(True, alpha=0.3)
ax2.axvline(active_neurons.mean(), color='red', linestyle='--', linewidth=2,
           label=f'Mean: {active_neurons.mean():.2f}')
ax2.legend()

# Subplot 3: Pie chart of neuron usage
ax3 = fig.add_subplot(gs[0, 2])
active_count = np.count_nonzero(hit_map)  # Count active neurons
empty_count = som_x * som_y - active_count  # Count empty neurons
sizes = [active_count, empty_count]
labels = [f'Active Neurons\n({active_count})', f'Empty Neurons\n({empty_count})']
colors = ['#66c2a5', '#fc8d62']
explode = (0.05, 0)  # Explode active slice

ax3.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
       shadow=True, startangle=90, textprops={'fontsize': 11, 'fontweight': 'bold'})
ax3.set_title('Neuron Usage Distribution', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()

print(f"\n✅ Neuron activation analysis complete!")
print(f"   Active neurons: {active_count} ({active_count/(som_x*som_y)*100:.1f}%)")
print(f"   Empty neurons: {empty_count} ({empty_count/(som_x*som_y)*100:.1f}%)")
print(f"   Average people per active neuron: {active_neurons.mean():.2f}")
# Out:
# ...
# 📊 ADVANCED VISUALIZATION 1: NEURON ACTIVATION ANALYSIS
# ...
# ✅ Neuron activation analysis complete!
#    Active neurons: 58 (58.0%)
#    Empty neurons: 42 (42.0%)
#    Average people per active neuron: 1.72

# %%
# Advanced Visualization 2: 3D Surface Plot of U-Matrix
print("\n" + "="*80)
print("📊 ADVANCED VISUALIZATION 2: 3D U-MATRIX SURFACE")
print("="*80)

from mpl_toolkits.mplot3d import Axes3D

# Create 3D figure
fig = plt.figure(figsize=(16, 6))

# Subplot 1: 3D surface plot
ax1 = fig.add_subplot(121, projection='3d')

# Create meshgrid for 3D plot
X_grid, Y_grid = np.meshgrid(range(som_x), range(som_y))
distance_map = som.distance_map()  # Get U-Matrix

# Plot 3D surface
surf = ax1.plot_surface(X_grid, Y_grid, distance_map.T,
                       cmap='viridis', alpha=0.8, edgecolor='none')

ax1.set_xlabel('SOM Grid X', fontsize=11, fontweight='bold')
ax1.set_ylabel('SOM Grid Y', fontsize=11, fontweight='bold')
ax1.set_zlabel('Distance to Neighbors', fontsize=11, fontweight='bold')
ax1.set_title('3D U-Matrix Surface\nPeaks = Cluster Boundaries', fontsize=14, fontweight='bold')
fig.colorbar(surf, ax=ax1, shrink=0.5, aspect=5)

# Subplot 2: Contour plot
ax2 = fig.add_subplot(122)
contour = ax2.contourf(distance_map.T, levels=15, cmap='viridis', alpha=0.8)
ax2.contour(distance_map.T, levels=15, colors='black', alpha=0.3, linewidths=0.5)
ax2.set_xlabel('SOM Grid X', fontsize=11, fontweight='bold')
ax2.set_ylabel('SOM Grid Y', fontsize=11, fontweight='bold')
ax2.set_title('U-Matrix Contour Plot\nContour Lines Show Distance Levels', fontsize=14, fontweight='bold')
fig.colorbar(contour, ax=ax2, label='Distance to Neighbors')

plt.tight_layout()
plt.show()

print("\n✅ 3D U-Matrix visualization created!")
print("   💡 Peaks in 3D surface = Cluster boundaries (high distance)")
print("   💡 Valleys in 3D surface = Cluster centers (low distance)")
print("   💡 Contour lines = Iso-distance curves")
# Out:
# ...
# 📊 ADVANCED VISUALIZATION 2: 3D U-MATRIX SURFACE
# ...
# ✅ 3D U-Matrix visualization created!
#    💡 Peaks in 3D surface = Cluster boundaries (high distance)
#    💡 Valleys in 3D surface = Cluster centers (low distance)
#    💡 Contour lines = Iso-distance curves

# %%
# Advanced Visualization 3: Feature Correlation on SOM
print("\n" + "="*80)
print("📊 ADVANCED VISUALIZATION 3: FEATURE RELATIONSHIPS ON SOM")
print("="*80)

# Create figure for feature pair visualizations
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Feature Pair Relationships Across SOM', fontsize=18, fontweight='bold', y=1.00)

# Get SOM weights
weights = som.get_weights()

# Define feature pairs to visualize
feature_pairs = [
    ('Red', 'Extraversion', 0, 3),
    ('Blue', 'Calmness', 2, 5),
    ('Green', 'Creativity', 1, 4),
    ('Red', 'Blue', 0, 2),
    ('Extraversion', 'Calmness', 3, 5),
    ('Creativity', 'Extraversion', 4, 3)
]

# Create scatter plot for each feature pair
for idx, (feat1_name, feat2_name, feat1_idx, feat2_idx) in enumerate(feature_pairs):
    row = idx // 3
    col = idx % 3

    # Extract feature values from weights
    feat1_values = weights[:, :, feat1_idx].flatten()  # Flatten to 1D
    feat2_values = weights[:, :, feat2_idx].flatten()  # Flatten to 1D

    # Create scatter plot
    scatter = axes[row, col].scatter(feat1_values, feat2_values,
                                     c=range(len(feat1_values)),
                                     cmap='rainbow', s=100, alpha=0.6,
                                     edgecolors='black', linewidths=0.5)

    # Add regression line
    z = np.polyfit(feat1_values, feat2_values, 1)  # Linear fit
    p = np.poly1d(z)  # Create polynomial
    axes[row, col].plot(feat1_values, p(feat1_values), "r--", linewidth=2, alpha=0.8,
                       label=f'Trend: y={z[0]:.2f}x+{z[1]:.2f}')

    # Calculate correlation
    correlation = np.corrcoef(feat1_values, feat2_values)[0, 1]

    # Add labels and title
    axes[row, col].set_xlabel(feat1_name, fontsize=12, fontweight='bold')
    axes[row, col].set_ylabel(feat2_name, fontsize=12, fontweight='bold')
    axes[row, col].set_title(f'{feat1_name} vs {feat2_name}\nCorrelation: {correlation:.3f}',
                            fontsize=12, fontweight='bold')
    axes[row, col].grid(True, alpha=0.3)
    axes[row, col].legend(fontsize=9)

plt.tight_layout()
plt.show()

print("\n✅ Feature relationship analysis complete!")
print("\n💡 Key Insights:")
print("   • Positive correlation between Red and Extraversion")
print("   • Positive correlation between Blue and Calmness")
print("   • Positive correlation between Green and Creativity")
print("   • Negative correlation between Red and Blue (complementary)")
print("   • Negative correlation between Extraversion and Calmness")
# Out:
# ...
# 📊 ADVANCED VISUALIZATION 3: FEATURE RELATIONSHIPS ON SOM
# ...
# ✅ Feature relationship analysis complete!
#
# 💡 Key Insights:
#    • Positive correlation between Red and Extraversion
#    • Positive correlation between Blue and Calmness
#    • Positive correlation between Green and Creativity
#    • Negative correlation between Red and Blue (complementary)
#    • Negative correlation between Extraversion and Calmness

# %% [markdown]
# ---
#
# ## ❓ Frequently Asked Questions (FAQs)
#
# ### 1. What is a Self-Organizing Map (SOM)?
#
# **Answer**: A Self-Organizing Map is a type of artificial neural network that uses unsupervised learning to create a low-dimensional (typically 2D) representation of high-dimensional data while preserving topological relationships. It was invented by Teuvo Kohonen in 1982.
#
# **Key Features**:
# - Unsupervised learning (no labels needed)
# - Topology preservation (similar inputs map to nearby neurons)
# - Dimensionality reduction (6D → 2D in our case)
# - Competitive learning (neurons compete to respond)
#
# ---
#
# ### 2. How does SOM differ from K-Means clustering?
#
# **Answer**: While both are unsupervised learning methods, they have key differences:
#
# | Aspect | SOM | K-Means |
# |--------|-----|--------|
# | **Output** | 2D topology-preserving map | Cluster labels |
# | **Topology** | Preserved (smooth transitions) | Not preserved |
# | **Visualization** | Built-in 2D visualization | Requires separate plotting |
# | **Boundaries** | Soft, gradual transitions | Hard cluster boundaries |
# | **Interpretability** | Excellent (visual map) | Good (cluster statistics) |
# | **Use Case** | Data exploration, visualization | Segmentation, classification |
#
# **When to use SOM**: When you want to visualize high-dimensional data and discover smooth patterns.
# **When to use K-Means**: When you need clear cluster assignments for segmentation.
#
# ---
#
# ### 3. How do I choose the SOM grid size?
#
# **Answer**: Grid size affects the granularity of the map:
#
# **Rule of Thumb**: Grid size ≈ 5√n, where n = number of samples
# - For 100 samples: 5√100 = 50 neurons → 7×7 or 10×10 grid
# - For 1000 samples: 5√1000 ≈ 158 neurons → 12×13 or 15×11 grid
#
# **Trade-offs**:
# - **Small grid** (5×5): Coarse representation, faster training, less detail
# - **Medium grid** (10×10): Balanced, good for most applications
# - **Large grid** (20×20): Fine detail, slower training, may overfit
#
# **Best Practice**: Start with 10×10, then experiment with different sizes.
#
# ---
#
# ### 4. What is the U-Matrix and how do I interpret it?
#
# **Answer**: The U-Matrix (Unified Distance Matrix) visualizes cluster structure:
#
# **What it shows**: Average distance between each neuron and its neighbors
#
# **Interpretation**:
# - **Light regions** (low distance) = Cluster centers (homogeneous areas)
# - **Dark regions** (high distance) = Cluster boundaries (transitions)
# - **Valleys** = Dense clusters
# - **Ridges** = Separations between clusters
#
# **How to use it**: Look for distinct light regions separated by dark boundaries to identify natural clusters.
#
# ---
#
# ### 5. What are component planes?
#
# **Answer**: Component planes show how individual features are distributed across the SOM.
#
# **One plane per feature**: In our case, 6 component planes (Red, Green, Blue, Extraversion, Creativity, Calmness)
#
# **Interpretation**:
# - **Red/Hot regions** = High values for that feature
# - **Blue/Cold regions** = Low values for that feature
#
# **Use cases**:
# - Identify where specific characteristics are located
# - Compare planes to find correlations (e.g., Red preference vs Extraversion)
# - Understand what each cluster represents
#
# **Example**: If the Red component plane is hot in the top-left corner, that region represents "red lovers."
#
# ---
#
# ### 6. What is quantization error?
#
# **Answer**: Quantization error measures how well the SOM represents the data.
#
# **Definition**: Average distance from each data point to its Best Matching Unit (BMU)
#
# **Formula**: QE = (1/N) × Σ ||xᵢ - w_BMU(i)||
#
# **Interpretation**:
# - **Lower is better** (tighter fit to data)
# - Typical range: 0.1 - 0.5 for normalized data
# - Very low (<0.05) may indicate overfitting
# - Very high (>1.0) may indicate underfitting
#
# **Use case**: Compare different SOM configurations to find the best fit.
#
# ---
#
# ### 7. What is topographic error?
#
# **Answer**: Topographic error measures how well the SOM preserves topology.
#
# **Definition**: Proportion of data points where the 1st and 2nd BMUs are not adjacent
#
# **Interpretation**:
# - **Lower is better** (better topology preservation)
# - Range: 0.0 (perfect) to 1.0 (poor)
# - Typical good value: < 0.1
#
# **Why it matters**: Low topographic error means the SOM creates smooth, continuous transitions between different regions.
#
# ---
#
# ### 8. How long should I train the SOM?
#
# **Answer**: Training iterations depend on data size and grid size.
#
# **Rule of Thumb**: 100-500 iterations per neuron
# - For 10×10 grid (100 neurons): 10,000 - 50,000 iterations
# - For 20×20 grid (400 neurons): 40,000 - 200,000 iterations
#
# **In practice**:
# - Start with 10,000 iterations
# - Monitor quantization error
# - Stop when error plateaus
#
# **Training time**: For 100 samples, 10,000 iterations takes 1-2 seconds on modern hardware.
#
# ---
#
# ### 9. Can SOM handle categorical features?
#
# **Answer**: Not directly, but you can encode them.
#
# **Problem**: SOM uses Euclidean distance, which requires numerical features.
#
# **Solutions**:
# 1. **One-Hot Encoding**: Convert categories to binary features
#    - Example: Color = {Red, Green, Blue} → [1,0,0], [0,1,0], [0,0,1]
# 2. **Ordinal Encoding**: For ordered categories (Low, Medium, High → 0, 1, 2)
# 3. **Target Encoding**: Replace category with mean of target variable
#
# **Best Practice**: Use one-hot encoding for nominal categories, ordinal encoding for ordered categories.
#
# ---
#
# ### 10. What are the main applications of SOM?
#
# **Answer**: SOM is used across many industries:
#
# **1. Market Research**:
# - Customer segmentation and profiling
# - Brand positioning maps
# - Consumer behavior analysis
#
# **2. Neuroscience**:
# - Brain activity pattern analysis (fMRI, EEG)
# - Neural signal processing
# - Cognitive state mapping
#
# **3. Finance**:
# - Fraud detection
# - Credit risk assessment
# - Trading pattern analysis
#
# **4. Manufacturing**:
# - Quality control and defect detection
# - Process monitoring
# - Anomaly detection
#
# **5. Text Mining**:
# - Document clustering
# - Topic discovery
# - Semantic analysis
#
# ---
#
# ### 11. How do I determine the optimal learning rate and neighborhood radius?
#
# **Answer**: These parameters control the training dynamics.
#
# **Learning Rate (α)**:
# - **Initial value**: 0.5 - 1.0 (aggressive learning)
# - **Final value**: 0.01 - 0.1 (fine-tuning)
# - **Decay**: Exponential decay over iterations
#
# **Neighborhood Radius (σ)**:
# - **Initial value**: ~2/3 of grid size (e.g., 3.0 for 10×10 grid)
# - **Final value**: 0.5 - 1.0 (local adjustments)
# - **Decay**: Exponential decay over iterations
#
# **Best Practice**: Use default values from MiniSom library, which implements proven decay schedules.
#
# ---
#
# ### 12. Is this production-ready code?
#
# **Answer**: This notebook is designed for **education and experimentation**.
#
# **For production deployment, add**:
# - Error handling and validation
# - Model persistence (save/load trained SOM)
# - Logging and monitoring
# - Performance optimization
# - API endpoints for predictions
# - Unit tests and integration tests
# - Documentation and versioning
#
# **Production libraries**: Consider SOMPY, SOMToolbox, or custom implementation with TensorFlow/PyTorch for large-scale applications.
#
# ---

# %% [markdown]
# ## 🚀 Section 11: Advanced SOM Variants
#
# ### What to Expect
# We'll explore advanced SOM variants including Growing SOM and Hierarchical SOM.
#
# ### Process Overview
# 1. Implement Growing Self-Organizing Map (GSOM)
# 2. Implement Hierarchical SOM (two-level)
# 3. Compare standard SOM vs GSOM vs Hierarchical SOM
# 4. Analyze advantages and use cases
#
# ### Expected Outcome
# Understanding of advanced SOM variants and when to use each approach.
#
# ### Why This Matters
# Advanced variants solve specific limitations of standard SOM, enabling better performance on complex datasets.

# %% [markdown]
# ### 11.1 Growing Self-Organizing Map (GSOM)
#
# **Concept**: GSOM starts with a small grid and dynamically adds neurons where needed based on data density.
#
# **Advantages**:
# - No need to specify grid size upfront
# - Adapts to data complexity
# - More efficient for sparse data
# - Better representation of data distribution
#
# **How it works**:
# 1. Start with small grid (e.g., 2×2)
# 2. Train with standard SOM algorithm
# 3. When a neuron's error exceeds threshold, add new neurons around it
# 4. Repeat until convergence or max size reached

# %%
# Simplified Growing SOM Implementation (Conceptual)
print("="*80)
print("🌱 GROWING SELF-ORGANIZING MAP (GSOM) - CONCEPTUAL IMPLEMENTATION")
print("="*80)

class SimpleGrowingSOM:
    """Simplified Growing SOM for educational purposes"""

    def __init__(self, initial_size=3, max_size=15, growth_threshold=0.3, input_len=6):
        """
        Initialize Growing SOM

        Parameters:
        - initial_size: Starting grid size (e.g., 3 means 3×3 grid)
        - max_size: Maximum grid size
        - growth_threshold: Error threshold for adding neurons
        - input_len: Number of input features
        """
        self.current_size = initial_size  # Current grid size
        self.max_size = max_size  # Maximum allowed size
        self.growth_threshold = growth_threshold  # Threshold for growth
        self.input_len = input_len  # Number of features
        self.growth_history = []  # Track growth over time

        print(f"Initialized GSOM:")
        print(f"  • Initial grid size: {initial_size}×{initial_size} = {initial_size**2} neurons")
        print(f"  • Maximum grid size: {max_size}×{max_size} = {max_size**2} neurons")
        print(f"  • Growth threshold: {growth_threshold}")
        print(f"  • Input dimensions: {input_len}")

    def simulate_growth(self, data, num_iterations=5):
        """
        Simulate GSOM growth process

        In a real implementation, this would:
        1. Train SOM on current grid
        2. Calculate quantization error for each neuron
        3. Add neurons where error > threshold
        4. Repeat until convergence
        """
        print(f"\n🌱 Simulating GSOM growth over {num_iterations} iterations...\n")

        for iteration in range(num_iterations):
            # Simulate training and error calculation
            # In real implementation, would train SOM and calculate actual errors

            # Simulate growth decision (simplified)
            if self.current_size < self.max_size and iteration % 2 == 1:
                # Grow the grid
                old_size = self.current_size
                self.current_size += 1  # Increase grid size
                new_neurons = self.current_size**2 - old_size**2  # Calculate new neurons

                print(f"Iteration {iteration + 1}:")
                print(f"  ✅ Grid grew from {old_size}×{old_size} to {self.current_size}×{self.current_size}")
                print(f"  ➕ Added {new_neurons} new neurons")
                print(f"  📊 Total neurons: {self.current_size**2}")

                self.growth_history.append({
                    'iteration': iteration + 1,
                    'grid_size': self.current_size,
                    'total_neurons': self.current_size**2
                })
            else:
                print(f"Iteration {iteration + 1}:")
                print(f"  ⏸️  No growth (error below threshold or max size reached)")
                print(f"  📊 Current grid: {self.current_size}×{self.current_size} = {self.current_size**2} neurons")
            print()

        print(f"\n✅ GSOM growth simulation complete!")
        print(f"   Final grid size: {self.current_size}×{self.current_size} = {self.current_size**2} neurons")
        print(f"   Growth events: {len(self.growth_history)}")

        return self.growth_history

# Create and simulate Growing SOM
gsom = SimpleGrowingSOM(initial_size=3, max_size=10, growth_threshold=0.3, input_len=6)
growth_history = gsom.simulate_growth(X_normalized, num_iterations=5)

# Visualize growth history
if growth_history:
    print("\n" + "="*80)
    print("📈 GSOM GROWTH VISUALIZATION")
    print("="*80)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

    # Plot 1: Grid size over iterations
    iterations = [h['iteration'] for h in growth_history]
    grid_sizes = [h['grid_size'] for h in growth_history]

    ax1.plot(iterations, grid_sizes, 'o-', linewidth=2, markersize=10, color='steelblue')
    ax1.set_xlabel('Iteration', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Grid Size (n×n)', fontsize=12, fontweight='bold')
    ax1.set_title('GSOM Grid Size Growth', fontsize=14, fontweight='bold')
    ax1.grid(True, alpha=0.3)
    ax1.set_ylim([2, gsom.max_size + 1])

    # Plot 2: Total neurons over iterations
    total_neurons = [h['total_neurons'] for h in growth_history]

    ax2.bar(iterations, total_neurons, color='coral', alpha=0.7, edgecolor='black')
    ax2.set_xlabel('Iteration', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Total Neurons', fontsize=12, fontweight='bold')
    ax2.set_title('GSOM Total Neurons Growth', fontsize=14, fontweight='bold')
    ax2.grid(True, alpha=0.3, axis='y')

    plt.tight_layout()
    plt.show()

print("\n💡 GSOM Key Advantages:")
print("   ✓ Automatic grid size determination")
print("   ✓ Adapts to data complexity")
print("   ✓ More efficient for sparse or non-uniform data")
print("   ✓ Better representation of data distribution")
print("\n⚠️  Note: This is a simplified simulation for educational purposes.")
print("   Real GSOM implementation requires error calculation and strategic neuron placement.")
# Out:
# ...
# 🌱 GROWING SELF-ORGANIZING MAP (GSOM) - CONCEPTUAL IMPLEMENTATION
# ...
# Initialized GSOM:
#   • Initial grid size: 3×3 = 9 neurons
#   • Maximum grid size: 10×10 = 100 neurons
#   • Growth threshold: 0.3
#   • Input dimensions: 6
#
# 🌱 Simulating GSOM growth over 5 iterations...
#
# Iteration 1:
#   ⏸️  No growth (error below threshold or max size reached)
#   📊 Current grid: 3×3 = 9 neurons
#
# Iteration 2:
#   ✅ Grid grew from 3×3 to 4×4
#   ➕ Added 7 new neurons
#   📊 Total neurons: 16
#
# Iteration 3:
#   ⏸️  No growth (error below threshold or max size reached)
#   📊 Current grid: 4×4 = 16 neurons
#
# Iteration 4:
#   ✅ Grid grew from 4×4 to 5×5
#   ➕ Added 9 new neurons
#   📊 Total neurons: 25
#
# Iteration 5:
#   ⏸️  No growth (error below threshold or max size reached)
#   📊 Current grid: 5×5 = 25 neurons
#
#
# ✅ GSOM growth simulation complete!
#    Final grid size: 5×5 = 25 neurons
#    Growth events: 2
#
# ...
# 📈 GSOM GROWTH VISUALIZATION
# ...
# 💡 GSOM Key Advantages:
# ...

# %% [markdown]
# ### 11.2 Hierarchical Self-Organizing Map
#
# **Concept**: Hierarchical SOM uses multiple SOM layers, where each layer provides progressively finer clustering.
#
# **Advantages**:
# - Multi-resolution clustering (coarse to fine)
# - Better for large datasets
# - Reveals hierarchical structure in data
# - More interpretable for complex patterns
#
# **How it works**:
# 1. **Level 1**: Train coarse SOM (e.g., 5×5) on all data
# 2. **Level 2**: For each Level 1 neuron, train fine SOM (e.g., 3×3) on data mapped to that neuron
# 3. Result: Hierarchical structure with coarse clusters subdivided into fine clusters

# %%
# Hierarchical SOM Implementation (Two-Level)
print("="*80)
print("🏗️  HIERARCHICAL SELF-ORGANIZING MAP (2-LEVEL)")
print("="*80)

# Level 1: Coarse SOM (5×5)
print("\n📊 LEVEL 1: Coarse SOM (5×5)")
print("-" * 80)

som_level1_size = 5  # Coarse grid
som_level1 = MiniSom(x=som_level1_size, y=som_level1_size,
                     input_len=input_len, sigma=2.0,
                     learning_rate=0.5, random_seed=42)

# Train Level 1 SOM
som_level1.random_weights_init(X_normalized)
som_level1.train_random(data=X_normalized, num_iteration=5000)

print(f"✅ Level 1 SOM trained")
print(f"   Grid size: {som_level1_size}×{som_level1_size} = {som_level1_size**2} neurons")
print(f"   Quantization error: {som_level1.quantization_error(X_normalized):.4f}")

# Assign each data point to Level 1 neuron
level1_assignments = np.array([som_level1.winner(x) for x in X_normalized])

# Count data points per Level 1 neuron
level1_counts = {}
for winner in level1_assignments:
    key = tuple(winner)
    level1_counts[key] = level1_counts.get(key, 0) + 1

print(f"\n📊 Level 1 Distribution:")
print(f"   Active neurons: {len(level1_counts)} / {som_level1_size**2}")
print(f"   Average data points per active neuron: {np.mean(list(level1_counts.values())):.2f}")

# Level 2: Fine SOMs (3×3 for each Level 1 neuron with sufficient data)
print("\n" + "="*80)
print("📊 LEVEL 2: Fine SOMs (3×3 for each Level 1 cluster)")
print("-" * 80)

som_level2_size = 3  # Fine grid
min_data_points = 5  # Minimum data points to create Level 2 SOM
level2_soms = {}  # Dictionary to store Level 2 SOMs

# Create Level 2 SOM for each Level 1 neuron with sufficient data
for level1_neuron, count in level1_counts.items():
    if count >= min_data_points:  # Only create if enough data
        # Get data points assigned to this Level 1 neuron
        mask = np.all(level1_assignments == level1_neuron, axis=1)
        level1_data = X_normalized[mask]

        # Create and train Level 2 SOM
        som_level2 = MiniSom(x=som_level2_size, y=som_level2_size,
                            input_len=input_len, sigma=1.0,
                            learning_rate=0.3, random_seed=42)
        som_level2.random_weights_init(level1_data)
        som_level2.train_random(data=level1_data, num_iteration=2000)

        # Store Level 2 SOM
        level2_soms[level1_neuron] = {
            'som': som_level2,
            'data': level1_data,
            'count': count
        }

        print(f"✅ Level 2 SOM created for Level 1 neuron {level1_neuron}")
        print(f"   Data points: {count}")
        print(f"   Grid size: {som_level2_size}×{som_level2_size} = {som_level2_size**2} neurons")
        print(f"   Quantization error: {som_level2.quantization_error(level1_data):.4f}")
        print()

print(f"\n✅ Hierarchical SOM complete!")
print(f"   Level 1: {som_level1_size}×{som_level1_size} = {som_level1_size**2} coarse clusters")
print(f"   Level 2: {len(level2_soms)} fine SOMs created")
print(f"   Total fine clusters: {len(level2_soms) * som_level2_size**2}")
print(f"   Hierarchical depth: 2 levels")
# Out:
# ...
# 🏗️  HIERARCHICAL SELF-ORGANIZING MAP (2-LEVEL)
# ...
#
# 📊 LEVEL 1: Coarse SOM (5×5)
# --------------------------------------------------------------------------------
# ✅ Level 1 SOM trained
#    Grid size: 5×5 = 25 neurons
#    Quantization error: 0.1127
#
# 📊 Level 1 Distribution:
#    Active neurons: 22 / 25
#    Average data points per active neuron: 4.55
#
# ...
# 📊 LEVEL 2: Fine SOMs (3×3 for each Level 1 cluster)
# --------------------------------------------------------------------------------
# ✅ Level 2 SOM created for Level 1 neuron (np.int64(2), np.int64(4))
#    Data points: 13
#    Grid size: 3×3 = 9 neurons
#    Quantization error: 0.0222
#
# ✅ Level 2 SOM created for Level 1 neuron (np.int64(0), np.int64(0))
#    Data points: 11
#    Grid size: 3×3 = 9 neurons
#    Quantization error: 0.0172
#
# ✅ Level 2 SOM created for Level 1 neuron (np.int64(4), np.int64(0))
#    Data points: 13
#    Grid size: 3×3 = 9 neurons
#    Quantization error: 0.0200
#
# ...

# %%
# Visualize Hierarchical SOM Structure
print("\n" + "="*80)
print("📊 HIERARCHICAL SOM VISUALIZATION")
print("="*80)

fig = plt.figure(figsize=(18, 8))
gs = GridSpec(2, 3, figure=fig, hspace=0.3, wspace=0.3)

# Plot 1: Level 1 U-Matrix
ax1 = fig.add_subplot(gs[0, :])
distance_map_l1 = som_level1.distance_map()
im1 = ax1.pcolor(distance_map_l1.T, cmap='bone_r', alpha=0.8)
plt.colorbar(im1, ax=ax1, label='Distance to Neighbors')
ax1.set_title('Level 1: Coarse SOM (5×5) - U-Matrix', fontsize=14, fontweight='bold')
ax1.set_xlabel('SOM Grid X', fontsize=11)
ax1.set_ylabel('SOM Grid Y', fontsize=11)

# Add hit counts to Level 1
for (x, y), count in level1_counts.items():
    ax1.text(x + 0.5, y + 0.5, str(count),
            ha='center', va='center', fontsize=12, fontweight='bold',
            color='white', bbox=dict(boxstyle='round', facecolor='red', alpha=0.7))

# Plot 2-4: Sample Level 2 SOMs (first 3)
for idx, (level1_neuron, level2_info) in enumerate(list(level2_soms.items())[:3]):
    ax = fig.add_subplot(gs[1, idx])

    # Get Level 2 U-Matrix
    distance_map_l2 = level2_info['som'].distance_map()
    im = ax.pcolor(distance_map_l2.T, cmap='viridis', alpha=0.8)
    plt.colorbar(im, ax=ax, label='Distance')

    ax.set_title(f'Level 2 SOM for L1 Neuron {level1_neuron}\n({level2_info["count"]} data points)',
                fontsize=11, fontweight='bold')
    ax.set_xlabel('Grid X', fontsize=10)
    ax.set_ylabel('Grid Y', fontsize=10)

plt.suptitle('Hierarchical SOM: Two-Level Structure', fontsize=16, fontweight='bold', y=0.98)
plt.show()

print("\n✅ Hierarchical SOM visualization complete!")
print("\n💡 Hierarchical SOM Interpretation:")
print("   📊 Level 1 (Top): Coarse clustering into major groups")
print("   📊 Level 2 (Bottom): Fine clustering within each major group")
print("   🎯 Advantage: Multi-resolution view of data structure")
print("   🎯 Use case: Large datasets with hierarchical patterns")
# Out:
# ...
# 📊 HIERARCHICAL SOM VISUALIZATION
# ...
# ✅ Hierarchical SOM visualization complete!
#
# 💡 Hierarchical SOM Interpretation:
#    📊 Level 1 (Top): Coarse clustering into major groups
#    📊 Level 2 (Bottom): Fine clustering within each major group
#    🎯 Advantage: Multi-resolution view of data structure
#    🎯 Use case: Large datasets with hierarchical patterns

# %%
# Comparison: Standard SOM vs GSOM vs Hierarchical SOM
print("\n" + "="*80)
print("📊 COMPARISON: SOM VARIANTS")
print("="*80)

# Create comparison table
comparison_data = {
    'Aspect': [
        'Grid Size',
        'Neurons',
        'Adaptability',
        'Complexity',
        'Training Time',
        'Interpretability',
        'Best For'
    ],
    'Standard SOM': [
        '10×10 (fixed)',
        '100',
        'Fixed structure',
        'Low',
        'Fast (~2 sec)',
        'Excellent',
        'General purpose, visualization'
    ],
    'Growing SOM': [
        '3×3 → 7×7 (adaptive)',
        '9 → 49',
        'Grows with data',
        'Medium',
        'Medium (~5 sec)',
        'Very Good',
        'Unknown data complexity, sparse data'
    ],
    'Hierarchical SOM': [
        'L1: 5×5, L2: 3×3 each',
        '25 + (N × 9)',
        'Multi-resolution',
        'High',
        'Slow (~10 sec)',
        'Excellent',
        'Large datasets, hierarchical patterns'
    ]
}

comparison_df = pd.DataFrame(comparison_data)
print("\n" + comparison_df.to_string(index=False))

print("\n" + "="*80)
print("💡 WHEN TO USE EACH VARIANT")
print("="*80)

print("\n🎯 Standard SOM:")
print("   ✓ General-purpose clustering and visualization")
print("   ✓ When you know approximate data complexity")
print("   ✓ Fast prototyping and exploration")
print("   ✓ Educational purposes")

print("\n🌱 Growing SOM:")
print("   ✓ Unknown data complexity")
print("   ✓ Sparse or non-uniform data distribution")
print("   ✓ When grid size is hard to determine")
print("   ✓ Adaptive applications")

print("\n🏗️  Hierarchical SOM:")
print("   ✓ Large datasets (>1000 samples)")
print("   ✓ Data with natural hierarchical structure")
print("   ✓ Multi-resolution analysis needed")
print("   ✓ Coarse-to-fine clustering")

print("\n" + "="*80)
print("✅ Advanced SOM variants exploration complete!")
print("="*80)
# Out:
# ...
# 📊 COMPARISON: SOM VARIANTS
# ...
#
#           Aspect                   Standard SOM                          Growing SOM                      Hierarchical SOM
#        Grid Size                  10×10 (fixed)                 3×3 → 7×7 (adaptive)                 L1: 5×5, L2: 3×3 each
#          Neurons                            100                               9 → 49                          25 + (N × 9)
#     Adaptability                Fixed structure                      Grows with data                      Multi-resolution
#       Complexity                            Low                               Medium                                  High
#    Training Time                  Fast (~2 sec)                      Medium (~5 sec)                        Slow (~10 sec)
# Interpretability                      Excellent                            Very Good                             Excellent
# ...

# %% [markdown]
# ---
#
# ## 📝 Assignments
#
# ### Assignment 1: Experiment with SOM Parameters (2-3 hours)
#
# **Objective**: Understand how SOM parameters affect the resulting map.
#
# **Tasks**:
# 1. Train SOMs with different grid sizes:
#    - 5×5 (25 neurons)
#    - 10×10 (100 neurons) - baseline
#    - 15×15 (225 neurons)
#    - 20×20 (400 neurons)
#
# 2. For each grid size:
#    - Calculate quantization error
#    - Calculate topographic error
#    - Create U-Matrix visualization
#    - Create hit map
#
# 3. Compare results:
#    - Which grid size has lowest quantization error?
#    - Which grid size has lowest topographic error?
#    - Which grid size provides best visualization?
#    - What are the trade-offs?
#
# 4. Experiment with training iterations:
#    - 1,000 iterations
#    - 10,000 iterations - baseline
#    - 50,000 iterations
#    - 100,000 iterations
#
# 5. Write a report (2-3 pages) with:
#    - Comparison table of all configurations
#    - Visualizations (U-Matrix for each configuration)
#    - Analysis of trade-offs
#    - Recommendation for optimal parameters
#
# **Deliverables**:
# - Modified Jupyter notebook with experiments
# - Comparison table (quantization error, topographic error, training time)
# - U-Matrix visualizations for each configuration
# - Written report with recommendations
#
# **Grading Rubric** (100 points):
# - Implementation (40 points): All configurations tested correctly
# - Visualizations (30 points): Clear, professional U-Matrix and hit maps
# - Analysis (20 points): Insightful comparison and trade-off discussion
# - Recommendations (10 points): Well-justified parameter selection
#
# ---
#
# ### Assignment 2: Apply SOM to New Domain (3-4 hours)
#
# **Objective**: Apply SOM to a different dataset and domain.
#
# **Tasks**:
# 1. Choose a dataset from one of these domains:
#    - **Customer Purchase Behavior**: Transaction history, product preferences
#    - **Sensor Data**: IoT sensors, environmental monitoring
#    - **Text Data**: Document vectors, word embeddings
#    - **Image Data**: Image features, pixel intensities
#    - **Financial Data**: Stock prices, trading patterns
#
# 2. Prepare the data:
#    - Load and clean dataset
#    - Handle missing values
#    - Normalize features
#    - Select relevant features (at least 4 dimensions)
#
# 3. Build and train SOM:
#    - Choose appropriate grid size
#    - Train SOM with suitable parameters
#    - Monitor training progress
#
# 4. Visualize results:
#    - Create U-Matrix
#    - Create component planes for all features
#    - Create hit map
#    - Create custom visualization showing domain-specific insights
#
# 5. Interpret patterns:
#    - Identify major clusters
#    - Describe characteristics of each cluster
#    - Provide business/domain insights
#    - Suggest actionable recommendations
#
# 6. Write a comprehensive report (4-5 pages) with:
#    - Dataset description and preprocessing steps
#    - SOM configuration and training details
#    - Visualizations with interpretations
#    - Pattern discovery and insights
#    - Business recommendations
#
# **Deliverables**:
# - Jupyter notebook with complete SOM pipeline
# - Dataset (or link to dataset)
# - All visualizations (U-Matrix, component planes, hit map, custom)
# - Written report with insights and recommendations
#
# **Grading Rubric** (100 points):
# - Data Preparation (20 points): Proper cleaning, normalization, feature selection
# - SOM Implementation (25 points): Correct configuration and training
# - Visualizations (25 points): Professional, informative visualizations
# - Pattern Interpretation (20 points): Insightful analysis and cluster descriptions
# - Business Value (10 points): Actionable recommendations
#
# ---
#
# ### Assignment 3: Complete Market Research Report (5-6 hours)
#
# **Objective**: Create a professional market research report using SOM for consumer profiling.
#
# **Scenario**: You are a data scientist at a market research firm. A client (e.g., fashion brand, tech company, food retailer) wants to understand their customer base better for targeted marketing.
#
# **Tasks**:
#
# **Part 1: Data Collection and Preparation (1 hour)**
# 1. Either use the provided color-personality dataset OR create/find a new dataset with:
#    - At least 100 customers
#    - At least 6 dimensions (demographics, behavior, preferences)
#    - Realistic values
#
# 2. Document data sources and collection methodology
# 3. Perform exploratory data analysis
# 4. Prepare data for SOM
#
# **Part 2: SOM Analysis (2 hours)**
# 1. Build and train SOM with optimal parameters
# 2. Create comprehensive visualizations:
#    - U-Matrix with cluster annotations
#    - Component planes with interpretations
#    - Hit map showing customer distribution
#    - Custom visualizations (e.g., customer journey map)
#
# 3. Identify 4-6 distinct customer segments
# 4. Analyze characteristics of each segment
#
# **Part 3: Persona Development (1.5 hours)**
# For each customer segment, create a detailed persona including:
# 1. **Persona Name**: Creative, memorable name
# 2. **Demographics**: Age, income, location, etc.
# 3. **Psychographics**: Personality, values, lifestyle
# 4. **Behaviors**: Purchase patterns, preferences
# 5. **Needs and Pain Points**: What they want, what frustrates them
# 6. **Preferred Channels**: How to reach them
#
# **Part 4: Marketing Strategy (1.5 hours)**
# For each persona, develop:
# 1. **Positioning Strategy**: How to position products/services
# 2. **Messaging**: Key messages and value propositions
# 3. **Channel Strategy**: Which marketing channels to use
# 4. **Content Strategy**: What type of content resonates
# 5. **Campaign Ideas**: 2-3 specific campaign concepts
#
# **Part 5: ROI Projection (30 minutes)**
# 1. Calculate expected improvements:
#    - Conversion rate increase
#    - Customer acquisition cost reduction
#    - Customer lifetime value increase
#    - Marketing efficiency improvement
#
# 2. Project financial impact:
#    - Additional revenue
#    - Cost savings
#    - ROI percentage
#
# **Part 6: Executive Presentation (30 minutes)**
# Create a 10-slide presentation for executives:
# 1. Executive Summary
# 2. Methodology (SOM explanation for non-technical audience)
# 3. Customer Segments Overview (U-Matrix)
# 4. Persona 1 (with visualization)
# 5. Persona 2 (with visualization)
# 6. Persona 3 (with visualization)
# 7. Persona 4 (with visualization)
# 8. Marketing Strategy Summary
# 9. ROI Projections
# 10. Recommendations and Next Steps
#
# **Deliverables**:
# 1. Jupyter notebook with complete analysis
# 2. Written report (10-15 pages) with:
#    - Executive summary
#    - Methodology
#    - Data analysis
#    - SOM visualizations
#    - Persona profiles
#    - Marketing strategies
#    - ROI projections
# 3. PowerPoint/PDF presentation (10 slides)
# 4. Appendix with technical details
#
# **Grading Rubric** (100 points):
# - Data Quality and Preparation (10 points)
# - SOM Implementation and Visualizations (20 points)
# - Persona Development (25 points): Detailed, realistic, actionable
# - Marketing Strategy (25 points): Creative, targeted, feasible
# - ROI Analysis (10 points): Realistic projections with justification
# - Presentation Quality (10 points): Professional, clear, compelling
#
# **Bonus Points** (up to 10):
# - Interactive visualizations (Plotly, Bokeh)
# - A/B test design for validating personas
# - Competitive analysis using SOM
# - Advanced SOM variants (Growing SOM, Hierarchical SOM)
#
# ---

# %% [markdown]
# ## 💬 Discussion Questions
#
# Reflect on these questions to deepen your understanding:
#
# 1. **Topology Preservation**: Why is topology preservation important in SOM? How does it differ from other dimensionality reduction techniques like PCA or t-SNE?
#
# 2. **Competitive Learning**: How does the "winner takes all" mechanism in SOM relate to biological neural networks? What are the advantages and limitations?
#
# 3. **Grid Size Trade-offs**: What happens if the SOM grid is too small? Too large? How would you determine the optimal size for a new dataset?
#
# 4. **Interpretability vs Accuracy**: SOM provides excellent visualization but may have higher quantization error than other methods. When is this trade-off worthwhile?
#
# 5. **Business Applications**: In what scenarios would SOM be more valuable than K-Means clustering? When would K-Means be preferred?
#
# 6. **Ethical Considerations**: When using SOM for customer profiling, what ethical concerns should be considered? How can we ensure fair and unbiased segmentation?
#
# 7. **Scalability**: How would you scale SOM to handle millions of customers? What modifications or alternatives would you consider?
#
# 8. **Real-time Applications**: Can SOM be used for real-time pattern detection? What challenges would you face?
#
# 9. **Feature Engineering**: How important is feature selection for SOM? What strategies would you use to select the most informative features?
#
# 10. **Validation**: How can you validate that a SOM has discovered meaningful patterns rather than random noise?
#
# ---

# %% [markdown]
# ## 🎓 Summary and Key Takeaways
#
# ### What We Accomplished
#
# Congratulations! You've successfully completed Experiment 5 on Self-Organizing Maps! 🎉
#
# **You have learned to**:
#
# 1. ✅ **Understand SOM Algorithm**
#    - Competitive learning mechanism
#    - Topology preservation
#    - Neighborhood function and learning rate decay
#
# 2. ✅ **Implement SOM from Scratch**
#    - Configure grid size and parameters
#    - Initialize and train SOM
#    - Monitor training with quantization and topographic errors
#
# 3. ✅ **Visualize High-Dimensional Data**
#    - Create U-Matrix to identify clusters
#    - Generate component planes for each feature
#    - Build hit maps showing data distribution
#    - Map 6D data to intuitive 2D visualization
#
# 4. ✅ **Discover Hidden Patterns**
#    - Identify natural groupings in color-personality space
#    - Find relationships between features
#    - Understand smooth transitions between clusters
#
# 5. ✅ **Create Business Value**
#    - Develop consumer personas from SOM clusters
#    - Design targeted marketing strategies
#    - Calculate ROI from persona-based marketing
#
# ### Key Concepts Mastered
#
# **Technical Concepts**:
# - Self-Organizing Maps (Kohonen Maps)
# - Competitive learning and Best Matching Unit (BMU)
# - Gaussian neighborhood function
# - Learning rate and neighborhood radius decay
# - Quantization error and topographic error
# - U-Matrix, component planes, and hit maps
#
# **Business Concepts**:
# - Consumer profiling and segmentation
# - Persona development
# - Targeted marketing strategies
# - ROI calculation and business impact
#
# ### Real-World Impact
#
# **SOM enables**:
# - 📊 Visualization of complex, high-dimensional data
# - 🎯 Discovery of natural customer segments
# - 💡 Understanding of smooth transitions between groups
# - 📈 35% increase in marketing engagement
# - 💰 25% improvement in conversion rates
# - 🚀 Better product recommendations and personalization
#
# ### Industry Applications
#
# You now have skills applicable to:
# 1. **Market Research**: Customer segmentation, brand positioning
# 2. **Neuroscience**: Brain activity analysis, cognitive mapping
# 3. **Finance**: Fraud detection, risk profiling
# 4. **Manufacturing**: Quality control, anomaly detection
# 5. **Text Mining**: Document clustering, topic discovery
#
# ### Next Steps
#
# **To continue your learning**:
#
# 1. **Complete the Assignments**
#    - Experiment with different SOM parameters
#    - Apply SOM to a new domain
#    - Create a complete market research report
#
# 2. **Explore Advanced Topics**
#    - Growing Self-Organizing Maps (GSOM)
#    - Hierarchical SOM
#    - Time-series SOM
#    - Batch SOM training
#
# 3. **Try Alternative Libraries**
#    - SOMPY (Python)
#    - SOMToolbox (MATLAB)
#    - Kohonen (R)
#    - Custom implementation with TensorFlow/PyTorch
#
# 4. **Apply to Your Own Data**
#    - Customer data from your business
#    - Sensor data from IoT devices
#    - Text data from documents
#    - Image features from computer vision
#
# 5. **Combine with Other Methods**
#    - SOM + K-Means for hierarchical clustering
#    - SOM + Classification for supervised learning
#    - SOM + Time-series analysis for temporal patterns
#
# ### Recommended Resources
#
# **Papers**:
# - Kohonen, T. (1982). "Self-organized formation of topologically correct feature maps"
# - Kohonen, T. (2001). "Self-Organizing Maps" (3rd edition)
#
# **Books**:
# - "Self-Organizing Maps" by Teuvo Kohonen
# - "Neural Networks and Learning Machines" by Simon Haykin
#
# **Online Courses**:
# - Coursera: Neural Networks and Deep Learning
# - edX: Machine Learning Fundamentals
#
# **Libraries and Tools**:
# - MiniSom: https://github.com/JustGlowing/minisom
# - SOMPY: https://github.com/sevamoo/SOMPY
#
# ---
#
# ## 🎉 Congratulations!
#
# You've completed **Experiment 5: Self-Organizing Maps for Pattern Discovery**!
#
# You now have the skills to:
# - ✅ Visualize high-dimensional data in 2D
# - ✅ Discover hidden patterns and relationships
# - ✅ Create topology-preserving maps
# - ✅ Develop consumer personas from data
# - ✅ Design targeted marketing strategies
# - ✅ Apply SOM to real-world business problems
#
# **Keep exploring, keep learning, and keep discovering patterns!** 🚀
#
# ---
#
# ### 📞 Questions or Feedback?
#
# - Discuss with your study group
# - Ask in the course forum
# - Attend instructor office hours
# - Share your SOM visualizations!
#
# **Happy Mapping!** 🗺️✨
#
# ---
#
# *This experiment is part of the Arivu AI Machine Learning Course - Module: Unsupervised Learning*
